# %%
import numpy as np
from matplotlib import pyplot as plt
from IPython import display

from envs import CollectData

# %%
dg = CollectData(K=4)

# %%
# Show a random trial
idx = np.random.randint(len(dg.ims))
for j in range(len(dg.ims[idx])):
    
    plt.clf()
    plt.imshow(dg.ims[idx][j])
    
    display.clear_output(wait=True)
    display.display(plt.gcf())
